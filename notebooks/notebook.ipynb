# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets  import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X, y = load_iris(return_X_y=True, as_frame=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2126, test_size=0.2)

df_train = X_train.copy()
df_train['Specie'] = y_train
df_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 91                 6.1               3.0                4.6               1.4
# 41                 4.5               2.3                1.3               0.3
# 112                6.8               3.0                5.5               2.1
# 119                6.0               2.2                5.0               1.5
# 136                6.3               3.4                5.6               2.4
# ..                 ...               ...                ...               ...
# 144                6.7               3.3                5.7               2.5
# 74                 6.4               2.9                4.3               1.3
# 44                 5.1               3.8                1.9               0.4
# 115                6.4               3.2                5.3               2.3
# 47                 4.6               3.2                1.4               0.2
#
#      Specie
# 91        1
# ...

# %%
#  Continuous values mean that Gaussian can be applied. Discrete require multinomial, as well as bernoulli

df_train.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 26                 5.0               3.4                1.6               0.4
# 78                 6.0               2.9                4.5               1.5
# 53                 5.5               2.3                4.0               1.3
# 50                 7.0               3.2                4.7               1.4
# 149                5.9               3.0                5.1               1.8
# 133                6.3               2.8                5.1               1.5
# 84                 5.4               3.0                4.5               1.5
# 68                 6.2               2.2                4.5               1.5
# 59                 5.2               2.7                3.9               1.4
# 118                7.7               2.6                6.9               2.3
#
#      Specie
# 26        0
# 78        1
# 53        1
# 50        1
# 149       2
# 133       2
# 84        1
# ...

# %%
df_train.describe().T
# Out:
#                    count      mean       std  min  25%   50%  75%  max
# sepal length (cm)  120.0  5.835833  0.828971  4.3  5.1  5.80  6.4  7.9
# sepal width (cm)   120.0  3.051667  0.446646  2.0  2.8  3.00  3.3  4.4
# petal length (cm)  120.0  3.780000  1.766714  1.0  1.5  4.35  5.1  6.9
# petal width (cm)   120.0  1.208333  0.760648  0.1  0.3  1.30  1.8  2.5
# Specie             120.0  1.016667  0.819749  0.0  0.0  1.00  2.0  2.0

# %%
df_train.hist()
plt.show()

# %%
sns.pairplot(data=df_train, hue='Specie')
plt.show()
# Out:
# /workspaces/naive_bayes/.venv/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X_train.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.066322           0.871955
# sepal width (cm)           -0.066322          1.000000          -0.400053
# petal length (cm)           0.871955         -0.400053           1.000000
# petal width (cm)            0.811665         -0.341626           0.962244
#
#                    petal width (cm)
# sepal length (cm)          0.811665
# sepal width (cm)          -0.341626
# petal length (cm)          0.962244
# petal width (cm)           1.000000

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_hat = model.predict(X_test)

print(f"Accuracy: {accuracy_score(y_test, y_hat):.2f}")
# Out:
# Accuracy: 0.87

# %%
#  decision tree, random forest, naive bayes

MODELS = {
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'RandomForestClassifier': RandomForestClassifier(),
    'Gaussian Naive Bayes': GaussianNB()
}

# %%
y_hat_predict = dict()

for name, model in MODELS.items():
    model.fit(X_train, y_train)
    y_hat_predict[name] = model.predict(X_test)

# %%
for name, y_hat_i in y_hat_predict.items():
    print(f"Classifier Name: {name} ---> Accuracy: {accuracy_score(y_test, y_hat_i):.2f}")
# Out:
# Classifier Name: Decision Tree Classifier ---> Accuracy: 0.90
# Classifier Name: RandomForestClassifier ---> Accuracy: 0.90
# Classifier Name: Gaussian Naive Bayes ---> Accuracy: 0.87

# %%
# lscpu terminal command for cpu specs

# %%
# Linux recommended programs:
# VS Code
# DBeaver
# Postman: APIs
# LibreOffice / Open Office
# Docker: Operating System Packaging with the models, programs created (for APIs)
# Firefox Browser
